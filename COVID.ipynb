# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from matplotlib import animation
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point
import earthpy as et 
from datetime import datetime
import matplotlib.image as mpimg
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
from math import log

# %%
sns.set(font_scale=1.5)
sns.set_style("white")

# %%
data = et.data.get_data('spatial-vector-lidar')
os.chdir(os.path.join(et.io.HOME, 'earth-analytics'))

# %%
worldBound_path = os.path.join("data", "spatial-vector-lidar", "global", 
                               "ne_110m_land", "ne_110m_land2.shp")
worldBound = gpd.read_file(worldBound_path)

# %%
# Plot worldBound data using geopandas
fig, ax = plt.subplots(figsize=(10, 5))
worldBound.plot(color='darkgrey', 
                ax=ax)
# Set the x and y axis labels
ax.set(xlabel="Longitude (Degrees)",
       ylabel="Latitude (Degrees)",
       title="Global Map - Geographic Coordinate System - WGS84 Datum\n Units: Degrees - Latitude / Longitude")

# Add the x y graticules
ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', 
              linestyle='dashed')
ax.xaxis.grid(color='gray', 
              linestyle='dashed')
#addlogo
logo = mpimg.imread('cqrclogo.png')
imagebox = OffsetImage(logo, zoom=.5)

ab = AnnotationBbox(imagebox, (160, -60),frameon=False)

ax.add_artist(ab)

# %%
from numpy import genfromtxt
my_data = genfromtxt('time_series_19-covid-Confirmed.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-4b6ca3aa7b92> in <module>
#       1 from numpy import genfromtxt
# ----> 2 my_data = genfromtxt('time_series_19-covid-Confirmed.csv', delimiter=',')
#
# ~/code/python-class/lib/python3.6/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2101             # Raise an exception ?
#    2102             if invalid_raise:
# -> 2103                 raise ValueError(errmsg)
#    2104             # Issue a warning ?
#    2105             else:
#
# ValueError: Some errors were detected !
#     Line #37 (got 52 columns instead of 51)
#     Line #38 (got 52 columns instead of 51)
#     Line #46 (got 52 columns instead of 51)
#     Line #48 (got 52 columns instead of 51)
#     Line #59 (got 52 columns instead of 51)
#     Line #66 (got 52 columns instead of 51)
#     Line #68 (got 52 columns instead of 51)
#     Line #70 (got 52 columns instead of 51)
#     Line #71 (got 52 columns instead of 51)
#     Line #74 (got 52 columns instead of 51)
#     Line #75 (got 52 columns instead of 51)
#     Line #77 (got 52 columns instead of 51)
#     Line #79 (got 52 columns instead of 51)
#     Line #80 (got 52 columns instead of 51)
#     Line #104 (got 52 columns instead of 51)
#     Line #115 (got 52 columns instead of 51)
#     Line #129 (got 52 columns instead of 51)
#     Line #130 (got 52 columns instead of 51)
#     Line #131 (got 52 columns instead of 51)
#     Line #132 (got 52 columns instead of 51)
#     Line #133 (got 52 columns instead of 51)
#     Line #134 (got 52 columns instead of 51)
#     Line #135 (got 52 columns instead of 51)
#     Line #136 (got 52 columns instead of 51)
#     Line #137 (got 52 columns instead of 51)
#     Line #141 (got 52 columns instead of 51)
#     Line #142 (got 52 columns instead of 51)
#     Line #143 (got 52 columns instead of 51)
#     Line #144 (got 52 columns instead of 51)
#     Line #147 (got 52 columns instead of 51)
#     Line #155 (got 52 columns instead of 51)
#     Line #159 (got 52 columns instead of 51)
#     Line #160 (got 52 columns instead of 51)
#     Line #161 (got 52 columns instead of 51)
#     Line #163 (got 52 columns instead of 51)
#     Line #164 (got 52 columns instead of 51)
#     Line #165 (got 52 columns instead of 51)
#     Line #166 (got 52 columns instead of 51)
#     Line #167 (got 52 columns instead of 51)
#     Line #168 (got 52 columns instead of 51)
#     Line #169 (got 52 columns instead of 51)
#     Line #170 (got 52 columns instead of 51)
#     Line #171 (got 52 columns instead of 51)
#     Line #172 (got 52 columns instead of 51)
#     Line #173 (got 52 columns instead of 51)
#     Line #176 (got 52 columns instead of 51)
#     Line #183 (got 52 columns instead of 51)
#     Line #184 (got 52 columns instead of 51)
#     Line #185 (got 52 columns instead of 51)
#     Line #186 (got 52 columns instead of 51)
#     Line #187 (got 52 columns instead of 51)
#     Line #188 (got 52 columns instead of 51)
#     Line #189 (got 52 columns instead of 51)
#     Line #190 (got 52 columns instead of 51)
#     Line #191 (got 52 columns instead of 51)
#     Line #192 (got 52 columns instead of 51)
#     Line #193 (got 52 columns instead of 51)
#     Line #195 (got 52 columns instead of 51)
#     Line #199 (got 52 columns instead of 51)
#     Line #200 (got 52 columns instead of 51)
#     Line #202 (got 52 columns instead of 51)
#     Line #203 (got 52 columns instead of 51)
#     Line #204 (got 52 columns instead of 51)
#     Line #205 (got 52 columns instead of 51)
#     Line #206 (got 52 columns instead of 51)
#     Line #207 (got 52 columns instead of 51)
#     Line #208 (got 52 columns instead of 51)
#     Line #209 (got 52 columns instead of 51)
#     Line #210 (got 52 columns instead of 51)
#     Line #211 (got 52 columns instead of 51)
#     Line #212 (got 52 columns instead of 51)
#     Line #213 (got 52 columns instead of 51)
#     Line #214 (got 52 columns instead of 51)
#     Line #215 (got 52 columns instead of 51)
#     Line #216 (got 52 columns instead of 51)
#     Line #217 (got 52 columns instead of 51)
#     Line #218 (got 52 columns instead of 51)
#     Line #219 (got 52 columns instead of 51)
#     Line #220 (got 52 columns instead of 51)
#     Line #221 (got 52 columns instead of 51)
#     Line #222 (got 52 columns instead of 51)
#     Line #223 (got 52 columns instead of 51)
#     Line #224 (got 52 columns instead of 51)
#     Line #228 (got 52 columns instead of 51)
#     Line #230 (got 52 columns instead of 51)
#     Line #231 (got 52 columns instead of 51)
#     Line #232 (got 52 columns instead of 51)
#     Line #235 (got 52 columns instead of 51)
#     Line #236 (got 52 columns instead of 51)
#     Line #237 (got 52 columns instead of 51)
#     Line #238 (got 52 columns instead of 51)
#     Line #239 (got 52 columns instead of 51)
#     Line #240 (got 52 columns instead of 51)
#     Line #241 (got 52 columns instead of 51)
#     Line #242 (got 52 columns instead of 51)
#     Line #243 (got 52 columns instead of 51)
#     Line #244 (got 52 columns instead of 51)
#     Line #245 (got 52 columns instead of 51)
#     Line #246 (got 52 columns instead of 51)
#     Line #247 (got 52 columns instead of 51)
#     Line #248 (got 52 columns instead of 51)
#     Line #249 (got 52 columns instead of 51)
#     Line #250 (got 52 columns instead of 51)
#     Line #251 (got 52 columns instead of 51)
#     Line #252 (got 52 columns instead of 51)
#     Line #253 (got 52 columns instead of 51)
#     Line #254 (got 52 columns instead of 51)
#     Line #255 (got 52 columns instead of 51)
#     Line #256 (got 52 columns instead of 51)

# %%
covid = pd.read_csv('time_series_19-covid-Confirmed2.csv')

# %%
covid
# Out:
#        Province/State  Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0                 NaN        Thailand  15.0000  101.0000        2        3
# 1                 NaN           Japan  36.0000  138.0000        2        1
# 2                 NaN       Singapore   1.2833  103.8333        0        1
# 3                 NaN           Nepal  28.1667   84.2500        0        0
# 4                 NaN        Malaysia   2.5000  112.5000        0        0
# ..                ...             ...      ...       ...      ...      ...
# 208  Saint Barthelemy          France  17.9000  -62.8333        0        0
# 209               NaN         Jamaica  18.1096  -77.2975        0        0
# 210               NaN         Reunion -21.1151   55.5364        0        0
# 211               NaN          Turkey  38.9637   35.2433        0        0
# 212         Gibraltar  United Kingdom  36.1408   -5.3536        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/3/20  3/4/20  3/5/20  3/6/20  \
# 0          5        7        8        8  ...      43      43      47      48
# 1          2        2        4        4  ...     293     331     360     420
# 2          3        3        4        5  ...     110     110     117     130
# 3          0        1        1        1  ...       1       1       1       1
# 4          0        3        4        4  ...      36      50      50      83
# ..       ...      ...      ...      ...  ...     ...     ...     ...     ...
# 208        0        0        0        0  ...       0       3       3       3
# 209        0        0        0        0  ...       0       0       0       0
# 210        0        0        0        0  ...       0       0       0       0
# 211        0        0        0        0  ...       0       0       0       0
# 212        0        0        0        0  ...       0       1       1       1
#
#      3/7/20  3/8/20  3/9/20  3/10/20  3/11/20  3/12/20
# 0        50      50      50       53       59       70
# 1       461     502     511      581      639      639
# 2       138     150     150      160      178      178
# 3         1       1       1        1        1        1
# 4        93      99     117      129      149      149
# ..      ...     ...     ...      ...      ...      ...
# 208       3       3       1        1        1        1
# 209       0       0       0        0        1        2
# 210       0       0       0        0        1        1
# 211       0       0       0        0        1        1
# 212       1       1       1        1        1        1
#
# [213 rows x 55 columns]

# %%
gdf = gpd.GeoDataFrame(
    covid, geometry=gpd.points_from_xy(covid.Long, covid.Lat))

# %%
gdfheaderlist = gdf.columns.tolist()
len(gdfheaderlist)-1
# Out:
# 55

# %%
DateN=gdf.columns.tolist()
for i in range(50,len(gdfheaderlist)-1): 
    fig, ax = plt.subplots(figsize=(12, 8))
    #ax.set(title='Corona virus cases')
    

    worldBound.plot(figsize=(10, 5), color='lightgrey',
               ax=ax)
    # remove the axis
    ax.axis('off')
    date_object = datetime.strptime(DateN[i], '%m/%d/%y')
    date_ready = date_object.strftime("%b %d")
    
    # title
    ax.annotate('COVID-19 cases',
               xy=(0.09, .85), xycoords='figure fraction',
               horizontalalignment='left', verticalalignment='top',
               fontsize=25, fontweight='bold', color='#555555')
    
    #date
    ax.annotate(date_ready,
               xy=(0.09, .63), xycoords='figure fraction',
               horizontalalignment='left', verticalalignment='top',
               fontsize=20, color='#555555')
    
    #known cases
    ax.annotate(f'{gdf.sum(axis=0)[i-1]:,}''\nknown cases',
               xy=(0.09, .57), xycoords='figure fraction',
               horizontalalignment='left', verticalalignment='top',
               fontsize=20, color='#555555')
    
    #source/byline
    ax.annotate('Source: Johns Hopkins University\nRandy Leonard/CQ Roll Call',
               xy=(0.09, .20), xycoords='figure fraction',
               horizontalalignment='left', verticalalignment='top',
               fontsize=12, color='#555555')

    # Add outbreak country/state locations
    size=gdf.iloc[:, [i]]
    gdf.plot(ax=ax, 
                color='coral', alpha=.6, 
                markersize=(size**.5)*3)
    
    #key
    ax.scatter([-90], [42], c='lightgray', alpha=1, zorder=-1, s=1**.5*3,
            label='1')
    ax.scatter([-90], [42], c='lightgray', alpha=.6, zorder=-1, s=500**.5*3,
            label='500')
    ax.scatter([-90], [42], c='lightgray', alpha=.6, zorder=-1, s=10000**.5*3,
            label='10,000')
    ax.scatter([-90], [42], c='lightgray', alpha=.6, zorder=-1, s=50000**.5*3,
            label='50,000')

    ax.legend( frameon=False,
        labelspacing=0.7, loc='lower left', fontsize=14, 
        bbox_to_anchor=(0.05,0.05), title_fontsize=20);
    #addlogo
    logo = mpimg.imread('cqrclogo.png')
    imagebox = OffsetImage(logo, zoom=.4)

    ab = AnnotationBbox(imagebox, (150, -62),frameon=False)

    ax.add_artist(ab)

    
    fig.savefig('testmap'+"{:0>2d}".format(i)+'.png', dpi=300, bbox_inches = 'tight',
    pad_inches = 0)

#with open('file_{0}.dat'.format(i),'w') as f:
       #f.write(str(func(i)))
    



    


# Setup x y axes with labels and add graticules

# %%
size
# Out:
#     1/22/20
# 0         1
# 1        14
# 2         6
# 3         1
# 4         0
# ..      ...
# 89        0
# 90        0
# 91        0
# 92        0
# 93        0
#
# [94 rows x 1 columns]

# %%
i=4
this="{:0>2d}".format(i)
print(this)
# Out:
# 04
